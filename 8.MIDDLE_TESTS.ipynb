# %%
from pathlib import Path
import xml.etree.ElementTree as ET
import shutil
import random

# -------------------------
# CONFIGURACIÓN DEL DATASET
# -------------------------

DRONE_ROOT = Path("data/DroneRGBT")      # carpeta original
OUT_ROOT   = DRONE_ROOT / "format_rgbt"  # carpeta de salida

SRC_TRAIN = "Train"   # con mayúscula
SRC_TEST  = "Test"    # con mayúscula

VAL_SPLIT = 0.2        # porcentaje de validación

IMG_EXTS = [".jpg", ".jpeg", ".png", ".bmp"]

# Tamaño fijo de la cajita alrededor de cada punto
BOX_PX = 10


# -------------------------
# FUNCIONES AUXILIARES
# -------------------------

def index_images(dir_path: Path, mode: str):
    """
    Crea un diccionario {clave -> ruta_imagen}.

    - Para RGB: clave = nombre base (ej: "1" para "1.jpg")
    - Para T:   clave = nombre base sin la R final (ej: "1" para "1R.jpg")
    """
    mapping = {}
    if not dir_path.exists():
        print(f"[WARN] Carpeta de imágenes no existe: {dir_path}")
        return mapping

    for p in dir_path.iterdir():
        if not p.is_file():
            continue
        if p.suffix.lower() not in IMG_EXTS:
            continue

        stem = p.stem
        if mode.lower() == "rgb":
            key = stem
        else:  # "t" / "ir"
            # quito una R/r final, si la tiene (1R -> 1, 23r -> 23)
            if stem.lower().endswith("r"):
                key = stem[:-1]
            else:
                key = stem
        mapping[key] = p

    print(f"[INFO] Indexadas {len(mapping)} imágenes en {dir_path} (modo={mode})")
    return mapping


def parse_xml_points(xml_path, box_px=BOX_PX):
    """Convierte un XML de DroneRGBT a líneas YOLO (cx, cy, w, h)."""
    tree = ET.parse(xml_path)
    root = tree.getroot()

    # Intento encontrar ancho/alto de forma robusta
    size = root.find("size")
    if size is None:
        size = root.find("./image/size")

    if size is None:
        raise ValueError(f"No se encontró <size> en {xml_path}")

    w = float(size.find("width").text)
    h = float(size.find("height").text)

    bw = box_px / w
    bh = box_px / h

    yolo = []

    for obj in root.findall("object"):
        name_tag = obj.find("name")
        if name_tag is None:
            continue
        if name_tag.text != "person":
            continue

        # Punto (x, y)
        point = obj.find("point")
        if point is None:
            point = obj.find("./points/point")
        if point is None:
            continue

        px = float(point.find("x").text)
        py = float(point.find("y").text)

        xc = px / w
        yc = py / h
        yolo.append(f"0 {xc:.6f} {yc:.6f} {bw:.6f} {bh:.6f}")

    return yolo

def prepare_split(xml_list, rgb_dir, ir_dir, dst_split):
    out_img_rgb = OUT_ROOT / "images" / dst_split / "rgb"
    out_img_t   = OUT_ROOT / "images" / dst_split / "t"
    out_lbl_dir = OUT_ROOT / "labels" / dst_split

    out_img_rgb.mkdir(parents=True, exist_ok=True)
    out_img_t.mkdir(parents=True, exist_ok=True)
    out_lbl_dir.mkdir(parents=True, exist_ok=True)

    # Indexo imágenes UNA sola vez por split
    rgb_map = index_images(rgb_dir, mode="rgb")
    ir_map  = index_images(ir_dir,  mode="t")

    total_xml = len(xml_list)
    ok_pairs  = 0
    no_imgs   = 0
    no_labels = 0

    for xml_path in xml_list:
        xml_stem = xml_path.stem       # p.ej. "1015R"

        # 🔴 clave "base" sin la R final (si la tiene)
        if xml_stem.lower().endswith("r"):
            key = xml_stem[:-1]        # "1015R" -> "1015"
        else:
            key = xml_stem

        print(f"[{dst_split}] Procesando {xml_stem} (key={key})...")

        # ahora sí, buscamos por la clave base
        rgb_path = rgb_map.get(key, None)
        ir_path  = ir_map.get(key, None)

        if rgb_path is None or ir_path is None:
            print(f"[WARN] Faltan imágenes RGB/T para {xml_stem} (RGB={rgb_path}, T={ir_path})")
            no_imgs += 1
            continue

        yolo_lines = parse_xml_points(xml_path)
        if not yolo_lines:
            # sin personas / sin labels
            no_labels += 1
            continue

        base_name = rgb_path.name
        base_stem = Path(base_name).stem

        label_path = out_lbl_dir / f"{base_stem}.txt"
        with open(label_path, "w") as f:
            f.write("\n".join(yolo_lines))

        shutil.copy2(rgb_path, out_img_rgb / base_name)
        shutil.copy2(ir_path,  out_img_t   / base_name)
        ok_pairs += 1

    print(f"[{dst_split}] XML totales: {total_xml}")
    print(f"[{dst_split}] Pares OK (img+T+label): {ok_pairs}")
    print(f"[{dst_split}] Sin imágenes emparejadas: {no_imgs}")
    print(f"[{dst_split}] Sin labels (0 personas): {no_labels}")


# -------------------------
# FUNCIÓN PRINCIPAL MODULAR
# -------------------------

def prepare_dronergbt(val_split=VAL_SPLIT):
    """
    Ejecuta todo el pipeline:
    - divide Train en train/val
    - procesa Test como test
    - convierte puntos a YOLO
    - copia imágenes RGB/T emparejadas
    - deja todo en format_rgbt/
    """

    # --- TRAIN ORIGINAL ---
    src_train = DRONE_ROOT / SRC_TRAIN
    train_gt_dir = src_train / "GT_"

    if not train_gt_dir.exists():
        raise FileNotFoundError(f"No existe carpeta de GT_ de Train: {train_gt_dir}")

    train_gt  = sorted(train_gt_dir.glob("*.xml"))
    train_rgb = src_train / "RGB"
    train_ir  = src_train / "Infrared"

    random.shuffle(train_gt)

    n_val = int(len(train_gt) * val_split)
    val_gt = train_gt[:n_val]
    train_gt_final = train_gt[n_val:]

    print(f"Total Train original: {len(train_gt)}")
    print(f"→ Train nuevo: {len(train_gt_final)}")
    print(f"→ Val nuevo:   {len(val_gt)}")

    prepare_split(train_gt_final, train_rgb, train_ir, "train")
    prepare_split(val_gt,         train_rgb, train_ir, "val")

    # --- TEST ORIGINAL ---
    src_test = DRONE_ROOT / SRC_TEST
    test_gt_dir = src_test / "GT_"

    if not test_gt_dir.exists():
        raise FileNotFoundError(f"No existe carpeta de GT_ de Test: {test_gt_dir}")

    test_gt  = sorted(test_gt_dir.glob("*.xml"))
    test_rgb = src_test / "RGB"
    test_ir  = src_test / "Infrared"

    print(f"Total Test original: {len(test_gt)}")

    prepare_split(test_gt, test_rgb, test_ir, "test")

    print("✔ Dataset DroneRGBT convertido a formato YOLO rgb+t en:", OUT_ROOT)


# Para ejecutarlo directamente como script:
if __name__ == "__main__":
    prepare_dronergbt()
# Out:
# Total Train original: 1807
# → Train nuevo: 1446
# → Val nuevo:   361
# [INFO] Indexadas 1807 imágenes en data\DroneRGBT\Train\RGB (modo=rgb)
# [INFO] Indexadas 1807 imágenes en data\DroneRGBT\Train\Infrared (modo=t)
# [train] Procesando 624R (key=624)...
# [train] Procesando 1098R (key=1098)...
# [train] Procesando 1617R (key=1617)...
# [train] Procesando 724R (key=724)...
# [train] Procesando 14R (key=14)...
# [train] Procesando 65R (key=65)...
# [train] Procesando 1801R (key=1801)...
# [train] Procesando 978R (key=978)...
# [train] Procesando 1109R (key=1109)...
# [train] Procesando 646R (key=646)...
# [train] Procesando 1766R (key=1766)...
# [train] Procesando 739R (key=739)...
# [train] Procesando 709R (key=709)...
# [train] Procesando 1265R (key=1265)...
# [train] Procesando 1726R (key=1726)...
# [train] Procesando 660R (key=660)...
# [train] Procesando 1581R (key=1581)...
# [train] Procesando 1697R (key=1697)...
# [train] Procesando 357R (key=357)...
# [train] Procesando 1287R (key=1287)...
# [train] Procesando 1255R (key=1255)...
# [train] Procesando 223R (key=223)...
# [train] Procesando 338R (key=338)...
# [train] Procesando 649R (key=649)...
# [train] Procesando 889R (key=889)...
# [train] Procesando 898R (key=898)...
# [train] Procesando 900R (key=900)...
# [train] Procesando 1426R (key=1426)...
# [train] Procesando 184R (key=184)...
# [train] Procesando 1048R (key=1048)...
# [train] Procesando 1645R (key=1645)...
# [train] Procesando 411R (key=411)...
# [train] Procesando 178R (key=178)...
# [train] Procesando 1181R (key=1181)...
# [train] Procesando 1427R (key=1427)...
# [train] Procesando 625R (key=625)...
# [train] Procesando 1290R (key=1290)...
# [train] Procesando 1730R (key=1730)...
# [train] Procesando 297R (key=297)...
# [train] Procesando 386R (key=386)...
# [train] Procesando 207R (key=207)...
# [train] Procesando 1415R (key=1415)...
# [train] Procesando 35R (key=35)...
# [train] Procesando 1135R (key=1135)...
# [train] Procesando 1103R (key=1103)...
# [train] Procesando 1374R (key=1374)...
# [train] Procesando 1672R (key=1672)...
# [train] Procesando 449R (key=449)...
# [train] Procesando 1276R (key=1276)...
# [train] Procesando 1802R (key=1802)...
# [train] Procesando 903R (key=903)...
# [train] Procesando 1563R (key=1563)...
# [train] Procesando 963R (key=963)...
# [train] Procesando 1110R (key=1110)...
# [train] Procesando 368R (key=368)...
# [train] Procesando 404R (key=404)...
# [train] Procesando 1353R (key=1353)...
# [train] Procesando 785R (key=785)...
# [train] Procesando 1552R (key=1552)...
# [train] Procesando 369R (key=369)...
# [train] Procesando 79R (key=79)...
# [train] Procesando 1134R (key=1134)...
# [train] Procesando 856R (key=856)...
# [train] Procesando 1149R (key=1149)...
# [train] Procesando 890R (key=890)...
# [train] Procesando 321R (key=321)...
# [train] Procesando 1302R (key=1302)...
# [train] Procesando 1038R (key=1038)...
# [train] Procesando 274R (key=274)...
# [train] Procesando 33R (key=33)...
# [train] Procesando 758R (key=758)...
# [train] Procesando 880R (key=880)...
# [train] Procesando 1747R (key=1747)...
# [train] Procesando 1077R (key=1077)...
# [train] Procesando 723R (key=723)...
# [train] Procesando 10R (key=10)...
# [train] Procesando 1170R (key=1170)...
# [train] Procesando 91R (key=91)...
# [train] Procesando 1035R (key=1035)...
# [train] Procesando 1540R (key=1540)...
# [train] Procesando 16R (key=16)...
# [train] Procesando 1476R (key=1476)...
# [train] Procesando 512R (key=512)...
# [train] Procesando 1608R (key=1608)...
# [train] Procesando 1180R (key=1180)...
# [train] Procesando 1014R (key=1014)...
# [train] Procesando 710R (key=710)...
# [train] Procesando 551R (key=551)...
# [train] Procesando 389R (key=389)...
# [train] Procesando 148R (key=148)...
# [train] Procesando 1653R (key=1653)...
# [train] Procesando 447R (key=447)...
# [train] Procesando 1054R (key=1054)...
# [train] Procesando 1575R (key=1575)...
# [train] Procesando 418R (key=418)...
# [train] Procesando 313R (key=313)...
# [train] Procesando 1333R (key=1333)...
# [train] Procesando 1598R (key=1598)...
# [train] Procesando 1344R (key=1344)...
# [train] Procesando 1806R (key=1806)...
# [train] Procesando 1597R (key=1597)...
# [train] Procesando 1056R (key=1056)...
# [train] Procesando 682R (key=682)...
# [train] Procesando 67R (key=67)...
# [train] Procesando 1804R (key=1804)...
# [train] Procesando 1501R (key=1501)...
# [train] Procesando 1779R (key=1779)...
# [train] Procesando 490R (key=490)...
# [train] Procesando 382R (key=382)...
# [train] Procesando 914R (key=914)...
# [train] Procesando 986R (key=986)...
# [train] Procesando 1052R (key=1052)...
# [train] Procesando 1182R (key=1182)...
# [train] Procesando 1006R (key=1006)...
# [train] Procesando 1679R (key=1679)...
# [train] Procesando 160R (key=160)...
# [train] Procesando 277R (key=277)...
# [train] Procesando 475R (key=475)...
# [train] Procesando 327R (key=327)...
# [train] Procesando 286R (key=286)...
# [train] Procesando 594R (key=594)...
# [train] Procesando 707R (key=707)...
# [train] Procesando 162R (key=162)...
# [train] Procesando 1756R (key=1756)...
# [train] Procesando 1651R (key=1651)...
# [train] Procesando 516R (key=516)...
# [train] Procesando 281R (key=281)...
# [train] Procesando 689R (key=689)...
# [train] Procesando 1605R (key=1605)...
# [train] Procesando 1395R (key=1395)...
# [train] Procesando 506R (key=506)...
# [train] Procesando 744R (key=744)...
# [train] Procesando 108R (key=108)...
# [train] Procesando 1021R (key=1021)...
# [train] Procesando 1582R (key=1582)...
# [train] Procesando 929R (key=929)...
# [train] Procesando 1754R (key=1754)...
# [train] Procesando 409R (key=409)...
# [train] Procesando 511R (key=511)...
# [train] Procesando 205R (key=205)...
# [train] Procesando 1745R (key=1745)...
# [train] Procesando 76R (key=76)...
# [train] Procesando 52R (key=52)...
# [train] Procesando 794R (key=794)...
# [train] Procesando 1340R (key=1340)...
# [train] Procesando 1487R (key=1487)...
# [train] Procesando 961R (key=961)...
# [train] Procesando 1343R (key=1343)...
# [train] Procesando 905R (key=905)...
# [train] Procesando 1670R (key=1670)...
# [train] Procesando 1572R (key=1572)...
# [train] Procesando 478R (key=478)...
# [train] Procesando 1479R (key=1479)...
# [train] Procesando 1168R (key=1168)...
# [train] Procesando 1703R (key=1703)...
# [train] Procesando 1112R (key=1112)...
# [train] Procesando 1473R (key=1473)...
# [train] Procesando 396R (key=396)...
# [train] Procesando 1422R (key=1422)...
# [train] Procesando 308R (key=308)...
# [train] Procesando 1472R (key=1472)...
# [train] Procesando 1345R (key=1345)...
# [train] Procesando 1194R (key=1194)...
# [train] Procesando 1591R (key=1591)...
# [train] Procesando 109R (key=109)...
# [train] Procesando 1478R (key=1478)...
# [train] Procesando 1049R (key=1049)...
# [train] Procesando 13R (key=13)...
# [train] Procesando 1633R (key=1633)...
# [train] Procesando 847R (key=847)...
# [train] Procesando 165R (key=165)...
# [train] Procesando 1068R (key=1068)...
# [train] Procesando 1225R (key=1225)...
# [train] Procesando 705R (key=705)...
# [train] Procesando 1577R (key=1577)...
# [train] Procesando 1731R (key=1731)...
# [train] Procesando 1086R (key=1086)...
# [train] Procesando 771R (key=771)...
# [train] Procesando 212R (key=212)...
# [train] Procesando 857R (key=857)...
# [train] Procesando 200R (key=200)...
# [train] Procesando 539R (key=539)...
# [train] Procesando 645R (key=645)...
# [train] Procesando 36R (key=36)...
# [train] Procesando 1482R (key=1482)...
# [train] Procesando 555R (key=555)...
# [train] Procesando 73R (key=73)...
# [train] Procesando 307R (key=307)...
# [train] Procesando 1274R (key=1274)...
# [train] Procesando 1465R (key=1465)...
# [train] Procesando 951R (key=951)...
# [train] Procesando 1157R (key=1157)...
# [train] Procesando 1690R (key=1690)...
# [train] Procesando 960R (key=960)...
# [train] Procesando 1718R (key=1718)...
# [train] Procesando 1179R (key=1179)...
# [train] Procesando 1675R (key=1675)...
# [train] Procesando 383R (key=383)...
# [train] Procesando 756R (key=756)...
# [train] Procesando 441R (key=441)...
# [train] Procesando 1161R (key=1161)...
# [train] Procesando 966R (key=966)...
# [train] Procesando 502R (key=502)...
# [train] Procesando 1354R (key=1354)...
# [train] Procesando 1100R (key=1100)...
# [train] Procesando 181R (key=181)...
# [train] Procesando 1142R (key=1142)...
# [train] Procesando 380R (key=380)...
# [train] Procesando 786R (key=786)...
# [train] Procesando 764R (key=764)...
# [train] Procesando 634R (key=634)...
# [train] Procesando 1381R (key=1381)...
# [train] Procesando 1564R (key=1564)...
# [train] Procesando 1152R (key=1152)...
# [train] Procesando 971R (key=971)...
# [train] Procesando 1601R (key=1601)...
# [train] Procesando 1491R (key=1491)...
# [train] Procesando 661R (key=661)...
# [train] Procesando 500R (key=500)...
# [train] Procesando 1084R (key=1084)...
# [train] Procesando 237R (key=237)...
# [train] Procesando 737R (key=737)...
# [train] Procesando 1081R (key=1081)...
# [train] Procesando 854R (key=854)...
# [train] Procesando 1256R (key=1256)...
# [train] Procesando 738R (key=738)...
# [train] Procesando 751R (key=751)...
# [train] Procesando 1407R (key=1407)...
# [train] Procesando 938R (key=938)...
# [train] Procesando 1031R (key=1031)...
# [train] Procesando 750R (key=750)...
# [train] Procesando 1305R (key=1305)...
# [train] Procesando 772R (key=772)...
# [train] Procesando 1559R (key=1559)...
# [train] Procesando 687R (key=687)...
# [train] Procesando 640R (key=640)...
# [train] Procesando 431R (key=431)...
# [train] Procesando 557R (key=557)...
# [train] Procesando 1624R (key=1624)...
# [train] Procesando 1527R (key=1527)...
# [train] Procesando 957R (key=957)...
# [train] Procesando 1053R (key=1053)...
# [train] Procesando 1178R (key=1178)...
# [train] Procesando 497R (key=497)...
# [train] Procesando 1483R (key=1483)...
# [train] Procesando 574R (key=574)...
# [train] Procesando 926R (key=926)...
# [train] Procesando 445R (key=445)...
# [train] Procesando 1044R (key=1044)...
# [train] Procesando 455R (key=455)...
# [train] Procesando 1452R (key=1452)...
# [train] Procesando 1262R (key=1262)...
# [train] Procesando 768R (key=768)...
# [train] Procesando 1402R (key=1402)...
# [train] Procesando 1273R (key=1273)...
# [train] Procesando 610R (key=610)...
# [train] Procesando 1399R (key=1399)...
# [train] Procesando 1504R (key=1504)...
# [train] Procesando 1335R (key=1335)...
# [train] Procesando 1794R (key=1794)...
# [train] Procesando 417R (key=417)...
# [train] Procesando 477R (key=477)...
# [train] Procesando 1206R (key=1206)...
# [train] Procesando 917R (key=917)...
# [train] Procesando 1738R (key=1738)...
# [train] Procesando 1640R (key=1640)...
# [train] Procesando 1438R (key=1438)...
# [train] Procesando 1560R (key=1560)...
# [train] Procesando 1363R (key=1363)...
# [train] Procesando 1709R (key=1709)...
# [train] Procesando 235R (key=235)...
# [train] Procesando 460R (key=460)...
# [train] Procesando 24R (key=24)...
# [train] Procesando 1195R (key=1195)...
# [train] Procesando 1246R (key=1246)...
# [train] Procesando 408R (key=408)...
# [train] Procesando 922R (key=922)...
# [train] Procesando 1308R (key=1308)...
# [train] Procesando 1441R (key=1441)...
# [train] Procesando 1541R (key=1541)...
# [train] Procesando 69R (key=69)...
# [train] Procesando 525R (key=525)...
# [train] Procesando 1652R (key=1652)...
# [train] Procesando 356R (key=356)...
# [train] Procesando 1393R (key=1393)...
# [train] Procesando 113R (key=113)...
# [train] Procesando 399R (key=399)...
# [train] Procesando 1096R (key=1096)...
# [train] Procesando 454R (key=454)...
# [train] Procesando 910R (key=910)...
# [train] Procesando 452R (key=452)...
# [train] Procesando 1508R (key=1508)...
# [train] Procesando 580R (key=580)...
# [train] Procesando 718R (key=718)...
# [train] Procesando 792R (key=792)...
# [train] Procesando 154R (key=154)...
# [train] Procesando 655R (key=655)...
# [train] Procesando 894R (key=894)...
# [train] Procesando 232R (key=232)...
# [train] Procesando 827R (key=827)...
# [train] Procesando 428R (key=428)...
# [train] Procesando 1339R (key=1339)...
# [train] Procesando 349R (key=349)...
# [train] Procesando 1012R (key=1012)...
# [train] Procesando 996R (key=996)...
# [train] Procesando 820R (key=820)...
# [train] Procesando 450R (key=450)...
# [train] Procesando 694R (key=694)...
# [train] Procesando 864R (key=864)...
# [train] Procesando 1486R (key=1486)...
# [train] Procesando 136R (key=136)...
# [train] Procesando 860R (key=860)...
# [train] Procesando 1294R (key=1294)...
# [train] Procesando 334R (key=334)...
# [train] Procesando 203R (key=203)...
# [train] Procesando 1536R (key=1536)...
# [train] Procesando 1566R (key=1566)...
# [train] Procesando 1513R (key=1513)...
# [train] Procesando 1490R (key=1490)...
# [train] Procesando 208R (key=208)...
# [train] Procesando 902R (key=902)...
# [train] Procesando 1095R (key=1095)...
# [train] Procesando 773R (key=773)...
# [train] Procesando 808R (key=808)...
# [train] Procesando 1619R (key=1619)...
# [train] Procesando 343R (key=343)...
# [train] Procesando 1414R (key=1414)...
# [train] Procesando 1411R (key=1411)...
# [train] Procesando 1397R (key=1397)...
# [train] Procesando 220R (key=220)...
# [train] Procesando 973R (key=973)...
# [train] Procesando 1571R (key=1571)...
# [train] Procesando 1594R (key=1594)...
# [train] Procesando 968R (key=968)...
# [train] Procesando 372R (key=372)...
# [train] Procesando 1489R (key=1489)...
# [train] Procesando 1349R (key=1349)...
# [train] Procesando 1377R (key=1377)...
# [train] Procesando 1791R (key=1791)...
# [train] Procesando 1082R (key=1082)...
# [train] Procesando 1474R (key=1474)...
# [train] Procesando 1764R (key=1764)...
# [train] Procesando 989R (key=989)...
# [train] Procesando 1516R (key=1516)...
# [train] Procesando 1555R (key=1555)...
# [train] Procesando 1160R (key=1160)...
# [train] Procesando 666R (key=666)...
# [train] Procesando 822R (key=822)...
# [train] Procesando 753R (key=753)...
# [train] Procesando 1520R (key=1520)...
# [train] Procesando 21R (key=21)...
# [train] Procesando 1046R (key=1046)...
# [train] Procesando 523R (key=523)...
# [train] Procesando 897R (key=897)...
# [train] Procesando 1416R (key=1416)...
# [train] Procesando 353R (key=353)...
# [train] Procesando 612R (key=612)...
# [train] Procesando 708R (key=708)...
# [train] Procesando 1063R (key=1063)...
# [train] Procesando 1299R (key=1299)...
# [train] Procesando 1367R (key=1367)...
# [train] Procesando 741R (key=741)...
# [train] Procesando 941R (key=941)...
# [train] Procesando 1431R (key=1431)...
# [train] Procesando 569R (key=569)...
# [train] Procesando 75R (key=75)...
# [train] Procesando 769R (key=769)...
# [train] Procesando 1005R (key=1005)...
# [train] Procesando 1242R (key=1242)...
# [train] Procesando 1558R (key=1558)...
# [train] Procesando 1270R (key=1270)...
# [train] Procesando 19R (key=19)...
# [train] Procesando 1267R (key=1267)...
# [train] Procesando 466R (key=466)...
# [train] Procesando 1610R (key=1610)...
# [train] Procesando 1362R (key=1362)...
# [train] Procesando 87R (key=87)...
# [train] Procesando 180R (key=180)...
# [train] Procesando 757R (key=757)...
# [train] Procesando 680R (key=680)...
# [train] Procesando 1229R (key=1229)...
# [train] Procesando 1221R (key=1221)...
# [train] Procesando 1526R (key=1526)...
# [train] Procesando 748R (key=748)...
# [train] Procesando 1529R (key=1529)...
# [train] Procesando 464R (key=464)...
# [train] Procesando 1398R (key=1398)...
# [train] Procesando 1492R (key=1492)...
# [train] Procesando 549R (key=549)...
# [train] Procesando 802R (key=802)...
# [train] Procesando 1674R (key=1674)...
# [train] Procesando 84R (key=84)...
# [train] Procesando 1615R (key=1615)...
# [train] Procesando 1089R (key=1089)...
# [train] Procesando 1437R (key=1437)...
# [train] Procesando 1219R (key=1219)...
# [train] Procesando 913R (key=913)...
# [train] Procesando 720R (key=720)...
# [train] Procesando 1700R (key=1700)...
# [train] Procesando 1116R (key=1116)...
# [train] Procesando 1010R (key=1010)...
# [train] Procesando 554R (key=554)...
# [train] Procesando 1203R (key=1203)...
# [train] Procesando 564R (key=564)...
# [train] Procesando 1220R (key=1220)...
# [train] Procesando 1463R (key=1463)...
# [train] Procesando 57R (key=57)...
# [train] Procesando 1511R (key=1511)...
# [train] Procesando 1627R (key=1627)...
# [train] Procesando 1450R (key=1450)...
# [train] Procesando 725R (key=725)...
# [train] Procesando 541R (key=541)...
# [train] Procesando 275R (key=275)...
# [train] Procesando 843R (key=843)...
# [train] Procesando 1015R (key=1015)...
# [train] Procesando 1477R (key=1477)...
# [train] Procesando 1760R (key=1760)...
# [train] Procesando 1043R (key=1043)...
# [train] Procesando 711R (key=711)...
# [train] Procesando 80R (key=80)...
# [train] Procesando 592R (key=592)...
# [train] Procesando 1417R (key=1417)...
# [train] Procesando 678R (key=678)...
# [train] Procesando 1058R (key=1058)...
# [train] Procesando 104R (key=104)...
# [train] Procesando 1579R (key=1579)...
# [train] Procesando 92R (key=92)...
# [train] Procesando 121R (key=121)...
# [train] Procesando 1701R (key=1701)...
# [train] Procesando 1165R (key=1165)...
# [train] Procesando 46R (key=46)...
# [train] Procesando 1448R (key=1448)...
# [train] Procesando 221R (key=221)...
# [train] Procesando 1028R (key=1028)...
# [train] Procesando 339R (key=339)...
# [train] Procesando 1286R (key=1286)...
# [train] Procesando 603R (key=603)...
# [train] Procesando 1686R (key=1686)...
# [train] Procesando 796R (key=796)...
# [train] Procesando 1534R (key=1534)...
# [train] Procesando 1757R (key=1757)...
# [train] Procesando 956R (key=956)...
# [train] Procesando 1434R (key=1434)...
# [train] Procesando 513R (key=513)...
# [train] Procesando 244R (key=244)...
# [train] Procesando 1334R (key=1334)...
# [train] Procesando 967R (key=967)...
# [train] Procesando 282R (key=282)...
# [train] Procesando 849R (key=849)...
# [train] Procesando 1503R (key=1503)...
# [train] Procesando 470R (key=470)...
# [train] Procesando 1027R (key=1027)...
# [train] Procesando 629R (key=629)...
# [train] Procesando 1064R (key=1064)...
# [train] Procesando 699R (key=699)...
# [train] Procesando 579R (key=579)...
# [train] Procesando 1696R (key=1696)...
# [train] Procesando 1453R (key=1453)...
# [train] Procesando 1204R (key=1204)...
# [train] Procesando 219R (key=219)...
# [train] Procesando 1139R (key=1139)...
# [train] Procesando 1120R (key=1120)...
# [train] Procesando 928R (key=928)...
# [train] Procesando 850R (key=850)...
# [train] Procesando 958R (key=958)...
# [train] Procesando 867R (key=867)...
# [train] Procesando 241R (key=241)...
# [train] Procesando 186R (key=186)...
# [train] Procesando 1466R (key=1466)...
# [train] Procesando 653R (key=653)...
# [train] Procesando 251R (key=251)...
# [train] Procesando 1020R (key=1020)...
# [train] Procesando 1301R (key=1301)...
# [train] Procesando 161R (key=161)...
# [train] Procesando 1595R (key=1595)...
# [train] Procesando 1192R (key=1192)...
# [train] Procesando 487R (key=487)...
# [train] Procesando 415R (key=415)...
# [train] Procesando 1066R (key=1066)...
# [train] Procesando 1351R (key=1351)...
# [train] Procesando 766R (key=766)...
# [train] Procesando 1400R (key=1400)...
# [train] Procesando 636R (key=636)...
# [train] Procesando 48R (key=48)...
# [train] Procesando 437R (key=437)...
# [train] Procesando 582R (key=582)...
# [train] Procesando 459R (key=459)...
# [train] Procesando 304R (key=304)...
# [train] Procesando 1585R (key=1585)...
# [train] Procesando 352R (key=352)...
# [train] Procesando 1446R (key=1446)...
# [train] Procesando 732R (key=732)...
# [train] Procesando 259R (key=259)...
# [train] Procesando 940R (key=940)...
# [train] Procesando 1728R (key=1728)...
# [train] Procesando 359R (key=359)...
# [train] Procesando 1309R (key=1309)...
# [train] Procesando 1325R (key=1325)...
# [train] Procesando 1553R (key=1553)...
# [train] Procesando 1211R (key=1211)...
# [train] Procesando 173R (key=173)...
# [train] Procesando 886R (key=886)...
# [train] Procesando 147R (key=147)...
# [train] Procesando 639R (key=639)...
# [train] Procesando 1787R (key=1787)...
# [train] Procesando 517R (key=517)...
# [train] Procesando 1239R (key=1239)...
# [train] Procesando 420R (key=420)...
# [train] Procesando 584R (key=584)...
# [train] Procesando 142R (key=142)...
# [train] Procesando 783R (key=783)...
# [train] Procesando 127R (key=127)...
# [train] Procesando 1186R (key=1186)...
# [train] Procesando 1723R (key=1723)...
# [train] Procesando 112R (key=112)...
# [train] Procesando 1702R (key=1702)...
# [train] Procesando 1099R (key=1099)...
# [train] Procesando 681R (key=681)...
# [train] Procesando 1226R (key=1226)...
# [train] Procesando 784R (key=784)...
# [train] Procesando 1365R (key=1365)...
# [train] Procesando 214R (key=214)...
# [train] Procesando 948R (key=948)...
# [train] Procesando 1144R (key=1144)...
# [train] Procesando 617R (key=617)...
# [train] Procesando 201R (key=201)...
# [train] Procesando 32R (key=32)...
# [train] Procesando 164R (key=164)...
# [train] Procesando 1443R (key=1443)...
# [train] Procesando 1722R (key=1722)...
# [train] Procesando 1460R (key=1460)...
# [train] Procesando 1550R (key=1550)...
# [train] Procesando 432R (key=432)...
# [train] Procesando 818R (key=818)...
# [train] Procesando 1778R (key=1778)...
# [train] Procesando 1347R (key=1347)...
# [train] Procesando 1115R (key=1115)...
# [train] Procesando 398R (key=398)...
# [train] Procesando 1338R (key=1338)...
# [train] Procesando 601R (key=601)...
# [train] Procesando 1772R (key=1772)...
# [train] Procesando 909R (key=909)...
# [train] Procesando 550R (key=550)...
# [train] Procesando 371R (key=371)...
# [train] Procesando 1532R (key=1532)...
# [train] Procesando 920R (key=920)...
# [train] Procesando 722R (key=722)...
# [train] Procesando 1782R (key=1782)...
# [train] Procesando 1269R (key=1269)...
# [train] Procesando 85R (key=85)...
# [train] Procesando 486R (key=486)...
# [train] Procesando 1240R (key=1240)...
# [train] Procesando 871R (key=871)...
# [train] Procesando 2R (key=2)...
# [train] Procesando 1724R (key=1724)...
# [train] Procesando 1714R (key=1714)...
# [train] Procesando 650R (key=650)...
# [train] Procesando 763R (key=763)...
# [train] Procesando 830R (key=830)...
# [train] Procesando 1512R (key=1512)...
# [train] Procesando 363R (key=363)...
# [train] Procesando 1388R (key=1388)...
# [train] Procesando 453R (key=453)...
# [train] Procesando 132R (key=132)...
# [train] Procesando 1029R (key=1029)...
# [train] Procesando 77R (key=77)...
# [train] Procesando 262R (key=262)...
# [train] Procesando 1249R (key=1249)...
# [train] Procesando 361R (key=361)...
# [train] Procesando 106R (key=106)...
# [train] Procesando 1655R (key=1655)...
# [train] Procesando 1557R (key=1557)...
# [train] Procesando 1484R (key=1484)...
# [train] Procesando 285R (key=285)...
# [train] Procesando 1688R (key=1688)...
# [train] Procesando 1749R (key=1749)...
# [train] Procesando 1786R (key=1786)...
# [train] Procesando 531R (key=531)...
# [train] Procesando 332R (key=332)...
# [train] Procesando 578R (key=578)...
# [train] Procesando 61R (key=61)...
# [train] Procesando 846R (key=846)...
# [train] Procesando 696R (key=696)...
# [train] Procesando 1544R (key=1544)...
# [train] Procesando 1254R (key=1254)...
# [train] Procesando 605R (key=605)...
# [train] Procesando 1126R (key=1126)...
# [train] Procesando 306R (key=306)...
# [train] Procesando 146R (key=146)...
# [train] Procesando 1037R (key=1037)...
# [train] Procesando 1625R (key=1625)...
# [train] Procesando 1771R (key=1771)...
# [train] Procesando 1227R (key=1227)...
# [train] Procesando 1191R (key=1191)...
# [train] Procesando 949R (key=949)...
# [train] Procesando 303R (key=303)...
# [train] Procesando 70R (key=70)...
# [train] Procesando 544R (key=544)...
# [train] Procesando 503R (key=503)...
# [train] Procesando 82R (key=82)...
# [train] Procesando 1136R (key=1136)...
# [train] Procesando 866R (key=866)...
# [train] Procesando 345R (key=345)...
# [train] Procesando 81R (key=81)...
# [train] Procesando 1528R (key=1528)...
# [train] Procesando 476R (key=476)...
# [train] Procesando 416R (key=416)...
# [train] Procesando 202R (key=202)...
# [train] Procesando 210R (key=210)...
# [train] Procesando 1567R (key=1567)...
# [train] Procesando 123R (key=123)...
# [train] Procesando 1199R (key=1199)...
# [train] Procesando 1604R (key=1604)...
# [train] Procesando 955R (key=955)...
# [train] Procesando 1131R (key=1131)...
# [train] Procesando 314R (key=314)...
# [train] Procesando 1725R (key=1725)...
# [train] Procesando 1281R (key=1281)...
# [train] Procesando 1708R (key=1708)...
# [train] Procesando 641R (key=641)...
# [train] Procesando 15R (key=15)...
# [train] Procesando 1609R (key=1609)...
# [train] Procesando 1525R (key=1525)...
# [train] Procesando 96R (key=96)...
# [train] Procesando 362R (key=362)...
# [train] Procesando 767R (key=767)...
# [train] Procesando 1499R (key=1499)...
# [train] Procesando 1072R (key=1072)...
# [train] Procesando 1531R (key=1531)...
# [train] Procesando 1210R (key=1210)...
# [train] Procesando 177R (key=177)...
# [train] Procesando 1634R (key=1634)...
# [train] Procesando 1094R (key=1094)...
# [train] Procesando 1570R (key=1570)...
# [train] Procesando 1667R (key=1667)...
# [train] Procesando 1644R (key=1644)...
# [train] Procesando 538R (key=538)...
# [train] Procesando 397R (key=397)...
# [train] Procesando 1803R (key=1803)...
# [train] Procesando 393R (key=393)...
# [train] Procesando 862R (key=862)...
# [train] Procesando 622R (key=622)...
# [train] Procesando 289R (key=289)...
# [train] Procesando 1051R (key=1051)...
# [train] Procesando 532R (key=532)...
# [train] Procesando 302R (key=302)...
# [train] Procesando 403R (key=403)...
# [train] Procesando 1457R (key=1457)...
# [train] Procesando 395R (key=395)...
# [train] Procesando 17R (key=17)...
# [train] Procesando 733R (key=733)...
# [train] Procesando 271R (key=271)...
# [train] Procesando 1519R (key=1519)...
# [train] Procesando 969R (key=969)...
# [train] Procesando 145R (key=145)...
# [train] Procesando 515R (key=515)...
# [train] Procesando 1125R (key=1125)...
# [train] Procesando 1223R (key=1223)...
# [train] Procesando 1023R (key=1023)...
# [train] Procesando 1117R (key=1117)...
# [train] Procesando 1260R (key=1260)...
# [train] Procesando 1257R (key=1257)...
# [train] Procesando 44R (key=44)...
# [train] Procesando 1796R (key=1796)...
# [train] Procesando 1469R (key=1469)...
# [train] Procesando 494R (key=494)...
# [train] Procesando 1458R (key=1458)...
# [train] Procesando 1424R (key=1424)...
# [train] Procesando 8R (key=8)...
# [train] Procesando 987R (key=987)...
# [train] Procesando 1451R (key=1451)...
# [train] Procesando 533R (key=533)...
# [train] Procesando 1657R (key=1657)...
# [train] Procesando 288R (key=288)...
# [train] Procesando 611R (key=611)...
# [train] Procesando 980R (key=980)...
# [train] Procesando 1548R (key=1548)...
# [train] Procesando 826R (key=826)...
# [train] Procesando 64R (key=64)...
# [train] Procesando 892R (key=892)...
# [train] Procesando 713R (key=713)...
# [train] Procesando 1768R (key=1768)...
# [train] Procesando 1222R (key=1222)...
# [train] Procesando 1494R (key=1494)...
# [train] Procesando 1762R (key=1762)...
# [train] Procesando 1327R (key=1327)...
# [train] Procesando 1576R (key=1576)...
# [train] Procesando 719R (key=719)...
# [train] Procesando 1710R (key=1710)...
# [train] Procesando 1336R (key=1336)...
# [train] Procesando 1735R (key=1735)...
# [train] Procesando 1217R (key=1217)...
# [train] Procesando 1713R (key=1713)...
# [train] Procesando 159R (key=159)...
# [train] Procesando 1057R (key=1057)...
# [train] Procesando 716R (key=716)...
# [train] Procesando 347R (key=347)...
# [train] Procesando 608R (key=608)...
# [train] Procesando 1366R (key=1366)...
# [train] Procesando 269R (key=269)...
# [train] Procesando 1322R (key=1322)...
# [train] Procesando 656R (key=656)...
# [train] Procesando 677R (key=677)...
# [train] Procesando 412R (key=412)...
# [train] Procesando 1739R (key=1739)...
# [train] Procesando 797R (key=797)...
# [train] Procesando 473R (key=473)...
# [train] Procesando 480R (key=480)...
# [train] Procesando 1740R (key=1740)...
# [train] Procesando 1368R (key=1368)...
# [train] Procesando 354R (key=354)...
# [train] Procesando 1285R (key=1285)...
# [train] Procesando 1124R (key=1124)...
# [train] Procesando 919R (key=919)...
# [train] Procesando 1041R (key=1041)...
# [train] Procesando 1304R (key=1304)...
# [train] Procesando 1378R (key=1378)...
# [train] Procesando 1074R (key=1074)...
# [train] Procesando 1271R (key=1271)...
# [train] Procesando 1800R (key=1800)...
# [train] Procesando 845R (key=845)...
# [train] Procesando 1248R (key=1248)...
# [train] Procesando 256R (key=256)...
# [train] Procesando 1097R (key=1097)...
# [train] Procesando 1288R (key=1288)...
# [train] Procesando 102R (key=102)...
# [train] Procesando 1108R (key=1108)...
# [train] Procesando 283R (key=283)...
# [train] Procesando 1009R (key=1009)...
# [train] Procesando 119R (key=119)...
# [train] Procesando 1556R (key=1556)...
# [train] Procesando 68R (key=68)...
# [train] Procesando 187R (key=187)...
# [train] Procesando 176R (key=176)...
# [train] Procesando 559R (key=559)...
# [train] Procesando 390R (key=390)...
# [train] Procesando 1455R (key=1455)...
# [train] Procesando 1140R (key=1140)...
# [train] Procesando 1406R (key=1406)...
# [train] Procesando 730R (key=730)...
# [train] Procesando 1656R (key=1656)...
# [train] Procesando 1442R (key=1442)...
# [train] Procesando 230R (key=230)...
# [train] Procesando 233R (key=233)...
# [train] Procesando 861R (key=861)...
# [train] Procesando 761R (key=761)...
# [train] Procesando 430R (key=430)...
# [train] Procesando 40R (key=40)...
# [train] Procesando 1059R (key=1059)...
# [train] Procesando 1631R (key=1631)...
# [train] Procesando 1763R (key=1763)...
# [train] Procesando 1252R (key=1252)...
# [train] Procesando 1630R (key=1630)...
# [train] Procesando 703R (key=703)...
# [train] Procesando 97R (key=97)...
# [train] Procesando 1R (key=1)...
# [train] Procesando 1244R (key=1244)...
# [train] Procesando 1087R (key=1087)...
# [train] Procesando 690R (key=690)...
# [train] Procesando 1632R (key=1632)...
# [train] Procesando 810R (key=810)...
# [train] Procesando 787R (key=787)...
# [train] Procesando 760R (key=760)...
# [train] Procesando 295R (key=295)...
# [train] Procesando 1593R (key=1593)...
# [train] Procesando 39R (key=39)...
# [train] Procesando 1101R (key=1101)...
# [train] Procesando 406R (key=406)...
# [train] Procesando 1166R (key=1166)...
# [train] Procesando 528R (key=528)...
# [train] Procesando 790R (key=790)...
# [train] Procesando 1436R (key=1436)...
# [train] Procesando 832R (key=832)...
# [train] Procesando 499R (key=499)...
# [train] Procesando 1065R (key=1065)...
# [train] Procesando 330R (key=330)...
# [train] Procesando 1662R (key=1662)...
# [train] Procesando 571R (key=571)...
# [train] Procesando 468R (key=468)...
# [train] Procesando 752R (key=752)...
# [train] Procesando 1687R (key=1687)...
# [train] Procesando 1088R (key=1088)...
# [train] Procesando 1107R (key=1107)...
# [train] Procesando 379R (key=379)...
# [train] Procesando 1543R (key=1543)...
# [train] Procesando 789R (key=789)...
# [train] Procesando 114R (key=114)...
# [train] Procesando 1755R (key=1755)...
# [train] Procesando 1000R (key=1000)...
# [train] Procesando 1201R (key=1201)...
# [train] Procesando 192R (key=192)...
# [train] Procesando 669R (key=669)...
# [train] Procesando 643R (key=643)...
# [train] Procesando 529R (key=529)...
# [train] Procesando 683R (key=683)...
# [train] Procesando 311R (key=311)...
# [train] Procesando 1428R (key=1428)...
# [train] Procesando 6R (key=6)...
# [train] Procesando 414R (key=414)...
# [train] Procesando 706R (key=706)...
# [train] Procesando 1173R (key=1173)...
# [train] Procesando 341R (key=341)...
# [train] Procesando 26R (key=26)...
# [train] Procesando 1435R (key=1435)...
# [train] Procesando 355R (key=355)...
# [train] Procesando 424R (key=424)...
# [train] Procesando 59R (key=59)...
# [train] Procesando 1155R (key=1155)...
# [train] Procesando 42R (key=42)...
# [train] Procesando 1447R (key=1447)...
# [train] Procesando 1187R (key=1187)...
# [train] Procesando 11R (key=11)...
# [train] Procesando 1583R (key=1583)...
# [train] Procesando 1751R (key=1751)...
# [train] Procesando 172R (key=172)...
# [train] Procesando 315R (key=315)...
# [train] Procesando 875R (key=875)...
# [train] Procesando 115R (key=115)...
# [train] Procesando 628R (key=628)...
# [train] Procesando 998R (key=998)...
# [train] Procesando 1364R (key=1364)...
# [train] Procesando 728R (key=728)...
# [train] Procesando 1060R (key=1060)...
# [train] Procesando 1773R (key=1773)...
# [train] Procesando 479R (key=479)...
# [train] Procesando 1677R (key=1677)...
# [train] Procesando 150R (key=150)...
# [train] Procesando 1545R (key=1545)...
# [train] Procesando 206R (key=206)...
# [train] Procesando 1004R (key=1004)...
# [train] Procesando 488R (key=488)...
# [train] Procesando 485R (key=485)...
# [train] Procesando 950R (key=950)...
# [train] Procesando 1036R (key=1036)...
# [train] Procesando 620R (key=620)...
# [train] Procesando 129R (key=129)...
# [train] Procesando 1761R (key=1761)...
# [train] Procesando 331R (key=331)...
# [train] Procesando 134R (key=134)...
# [train] Procesando 1387R (key=1387)...
# [train] Procesando 458R (key=458)...
# [train] Procesando 937R (key=937)...
# [train] Procesando 1184R (key=1184)...
# [train] Procesando 825R (key=825)...
# [train] Procesando 1233R (key=1233)...
# [train] Procesando 623R (key=623)...
# [train] Procesando 1530R (key=1530)...
# [train] Procesando 439R (key=439)...
# [train] Procesando 1715R (key=1715)...
# [train] Procesando 836R (key=836)...
# [train] Procesando 1706R (key=1706)...
# [train] Procesando 376R (key=376)...
# [train] Procesando 1167R (key=1167)...
# [train] Procesando 1355R (key=1355)...
# [train] Procesando 1183R (key=1183)...
# [train] Procesando 865R (key=865)...
# [train] Procesando 1589R (key=1589)...
# [train] Procesando 934R (key=934)...
# [train] Procesando 1647R (key=1647)...
# [train] Procesando 805R (key=805)...
# [train] Procesando 1018R (key=1018)...
# [train] Procesando 1496R (key=1496)...
# [train] Procesando 1371R (key=1371)...
# [train] Procesando 545R (key=545)...
# [train] Procesando 133R (key=133)...
# [train] Procesando 392R (key=392)...
# [train] Procesando 1076R (key=1076)...
# [train] Procesando 930R (key=930)...
# [train] Procesando 253R (key=253)...
# [train] Procesando 319R (key=319)...
# [train] Procesando 823R (key=823)...
# [train] Procesando 815R (key=815)...
# [train] Procesando 1215R (key=1215)...
# [train] Procesando 72R (key=72)...
# [train] Procesando 1259R (key=1259)...
# [train] Procesando 58R (key=58)...
# [train] Procesando 1158R (key=1158)...
# [train] Procesando 1568R (key=1568)...
# [train] Procesando 1379R (key=1379)...
# [train] Procesando 328R (key=328)...
# [train] Procesando 925R (key=925)...
# [train] Procesando 994R (key=994)...
# [train] Procesando 436R (key=436)...
# [train] Procesando 566R (key=566)...
# [train] Procesando 596R (key=596)...
# [train] Procesando 1236R (key=1236)...
# [train] Procesando 489R (key=489)...
# [train] Procesando 1646R (key=1646)...
# [train] Procesando 1612R (key=1612)...
# [train] Procesando 770R (key=770)...
# [train] Procesando 263R (key=263)...
# [train] Procesando 465R (key=465)...
# [train] Procesando 429R (key=429)...
# [train] Procesando 199R (key=199)...
# [train] Procesando 496R (key=496)...
# [train] Procesando 1542R (key=1542)...
# [train] Procesando 1769R (key=1769)...
# [train] Procesando 1034R (key=1034)...
# [train] Procesando 1459R (key=1459)...
# [train] Procesando 1562R (key=1562)...
# [train] Procesando 238R (key=238)...
# [train] Procesando 1775R (key=1775)...
# [train] Procesando 981R (key=981)...
# [train] Procesando 336R (key=336)...
# [train] Procesando 1799R (key=1799)...
# [train] Procesando 501R (key=501)...
# [train] Procesando 1720R (key=1720)...
# [train] Procesando 652R (key=652)...
# [train] Procesando 1681R (key=1681)...
# [train] Procesando 923R (key=923)...
# [train] Procesando 1475R (key=1475)...
# [train] Procesando 88R (key=88)...
# [train] Procesando 22R (key=22)...
# [train] Procesando 791R (key=791)...
# [train] Procesando 1306R (key=1306)...
# [train] Procesando 778R (key=778)...
# [train] Procesando 299R (key=299)...
# [train] Procesando 434R (key=434)...
# [train] Procesando 423R (key=423)...
# [train] Procesando 1078R (key=1078)...
# [train] Procesando 1238R (key=1238)...
# [train] Procesando 1586R (key=1586)...
# [train] Procesando 1500R (key=1500)...
# [train] Procesando 1277R (key=1277)...
# [train] Procesando 1247R (key=1247)...
# [train] Procesando 1202R (key=1202)...
# [train] Procesando 535R (key=535)...
# [train] Procesando 252R (key=252)...
# [train] Procesando 279R (key=279)...
# [train] Procesando 675R (key=675)...
# [train] Procesando 746R (key=746)...
# [train] Procesando 701R (key=701)...
# [train] Procesando 9R (key=9)...
# [train] Procesando 1622R (key=1622)...
# [train] Procesando 607R (key=607)...
# [train] Procesando 1386R (key=1386)...
# [train] Procesando 806R (key=806)...
# [train] Procesando 137R (key=137)...
# [train] Procesando 1698R (key=1698)...
# [train] Procesando 1209R (key=1209)...
# [train] Procesando 563R (key=563)...
# [train] Procesando 638R (key=638)...
# [train] Procesando 548R (key=548)...
# [train] Procesando 888R (key=888)...
# [train] Procesando 1694R (key=1694)...
# [train] Procesando 585R (key=585)...
# [train] Procesando 782R (key=782)...
# [train] Procesando 800R (key=800)...
# [train] Procesando 627R (key=627)...
# [train] Procesando 576R (key=576)...
# [train] Procesando 407R (key=407)...
# [train] Procesando 1360R (key=1360)...
# [train] Procesando 1547R (key=1547)...
# [train] Procesando 66R (key=66)...
# [train] Procesando 440R (key=440)...
# [train] Procesando 1329R (key=1329)...
# [train] Procesando 218R (key=218)...
# [train] Procesando 648R (key=648)...
# [train] Procesando 572R (key=572)...
# [train] Procesando 507R (key=507)...
# [train] Procesando 1774R (key=1774)...
# [train] Procesando 1055R (key=1055)...
# [train] Procesando 1314R (key=1314)...
# [train] Procesando 1569R (key=1569)...
# [train] Procesando 659R (key=659)...
# [train] Procesando 1380R (key=1380)...
# [train] Procesando 1213R (key=1213)...
# [train] Procesando 348R (key=348)...
# [train] Procesando 874R (key=874)...
# [train] Procesando 1456R (key=1456)...
# [train] Procesando 1689R (key=1689)...
# [train] Procesando 1013R (key=1013)...
# [train] Procesando 135R (key=135)...
# [train] Procesando 1682R (key=1682)...
# [train] Procesando 1495R (key=1495)...
# [train] Procesando 1798R (key=1798)...
# [train] Procesando 217R (key=217)...
# [train] Procesando 1069R (key=1069)...
# [train] Procesando 284R (key=284)...
# [train] Procesando 131R (key=131)...
# [train] Procesando 1671R (key=1671)...
# [train] Procesando 602R (key=602)...
# [train] Procesando 959R (key=959)...
# [train] Procesando 1551R (key=1551)...
# [train] Procesando 1578R (key=1578)...
# [train] Procesando 577R (key=577)...
# [train] Procesando 881R (key=881)...
# [train] Procesando 509R (key=509)...
# [train] Procesando 1537R (key=1537)...
# [train] Procesando 216R (key=216)...
# [train] Procesando 1330R (key=1330)...
# [train] Procesando 1654R (key=1654)...
# [train] Procesando 1293R (key=1293)...
# [train] Procesando 788R (key=788)...
# [train] Procesando 1106R (key=1106)...
# [train] Procesando 1062R (key=1062)...
# [train] Procesando 1637R (key=1637)...
# [train] Procesando 702R (key=702)...
# [train] Procesando 558R (key=558)...
# [train] Procesando 1759R (key=1759)...
# [train] Procesando 1331R (key=1331)...
# [train] Procesando 647R (key=647)...
# [train] Procesando 524R (key=524)...
# [train] Procesando 927R (key=927)...
# [train] Procesando 1188R (key=1188)...
# [train] Procesando 877R (key=877)...
# [train] Procesando 1729R (key=1729)...
# [train] Procesando 869R (key=869)...
# [train] Procesando 1618R (key=1618)...
# [train] Procesando 278R (key=278)...
# [train] Procesando 1137R (key=1137)...
# [train] Procesando 1663R (key=1663)...
# [train] Procesando 120R (key=120)...
# [train] Procesando 1481R (key=1481)...
# [train] Procesando 765R (key=765)...
# [train] Procesando 100R (key=100)...
# [train] Procesando 924R (key=924)...
# [train] Procesando 1216R (key=1216)...
# [train] Procesando 226R (key=226)...
# [train] Procesando 170R (key=170)...
# [train] Procesando 779R (key=779)...
# [train] Procesando 837R (key=837)...
# [train] Procesando 1628R (key=1628)...
# [train] Procesando 37R (key=37)...
# [train] Procesando 1807R (key=1807)...
# [train] Procesando 1011R (key=1011)...
# [train] Procesando 99R (key=99)...
# [train] Procesando 1454R (key=1454)...
# [train] Procesando 561R (key=561)...
# [train] Procesando 444R (key=444)...
# [train] Procesando 527R (key=527)...
# [train] Procesando 86R (key=86)...
# [train] Procesando 954R (key=954)...
# [train] Procesando 1497R (key=1497)...
# [train] Procesando 461R (key=461)...
# [train] Procesando 1141R (key=1141)...
# [train] Procesando 7R (key=7)...
# [train] Procesando 38R (key=38)...
# [train] Procesando 1128R (key=1128)...
# [train] Procesando 110R (key=110)...
# [train] Procesando 1251R (key=1251)...
# [train] Procesando 1040R (key=1040)...
# [train] Procesando 1517R (key=1517)...
# [train] Procesando 446R (key=446)...
# [train] Procesando 323R (key=323)...
# [train] Procesando 1156R (key=1156)...
# [train] Procesando 859R (key=859)...
# [train] Procesando 1669R (key=1669)...
# [train] Procesando 1611R (key=1611)...
# [train] Procesando 322R (key=322)...
# [train] Procesando 995R (key=995)...
# [train] Procesando 47R (key=47)...
# [train] Procesando 1114R (key=1114)...
# [train] Procesando 1001R (key=1001)...
# [train] Procesando 50R (key=50)...
# [train] Procesando 777R (key=777)...
# [train] Procesando 1017R (key=1017)...
# [train] Procesando 591R (key=591)...
# [train] Procesando 101R (key=101)...
# [train] Procesando 686R (key=686)...
# [train] Procesando 841R (key=841)...
# [train] Procesando 183R (key=183)...
# [train] Procesando 833R (key=833)...
# [train] Procesando 654R (key=654)...
# [train] Procesando 1047R (key=1047)...
# [train] Procesando 953R (key=953)...
# [train] Procesando 684R (key=684)...
# [train] Procesando 1561R (key=1561)...
# [train] Procesando 642R (key=642)...
# [train] Procesando 575R (key=575)...
# [train] Procesando 1148R (key=1148)...
# [train] Procesando 839R (key=839)...
# [train] Procesando 1264R (key=1264)...
# [train] Procesando 1752R (key=1752)...
# [train] Procesando 374R (key=374)...
# [train] Procesando 1603R (key=1603)...
# [train] Procesando 1616R (key=1616)...
# [train] Procesando 1705R (key=1705)...
# [train] Procesando 1750R (key=1750)...
# [train] Procesando 435R (key=435)...
# [train] Procesando 1317R (key=1317)...
# [train] Procesando 514R (key=514)...
# [train] Procesando 1588R (key=1588)...
# [train] Procesando 1635R (key=1635)...
# [train] Procesando 962R (key=962)...
# [train] Procesando 1313R (key=1313)...
# [train] Procesando 41R (key=41)...
# [train] Procesando 1599R (key=1599)...
# [train] Procesando 239R (key=239)...
# [train] Procesando 272R (key=272)...
# [train] Procesando 595R (key=595)...
# [train] Procesando 1776R (key=1776)...
# [train] Procesando 657R (key=657)...
# [train] Procesando 606R (key=606)...
# [train] Procesando 1707R (key=1707)...
# [train] Procesando 126R (key=126)...
# [train] Procesando 931R (key=931)...
# [train] Procesando 946R (key=946)...
# [train] Procesando 472R (key=472)...
# [train] Procesando 1673R (key=1673)...
# [train] Procesando 644R (key=644)...
# [train] Procesando 609R (key=609)...
# [train] Procesando 1268R (key=1268)...
# [train] Procesando 1111R (key=1111)...
# [train] Procesando 249R (key=249)...
# [train] Procesando 912R (key=912)...
# [train] Procesando 156R (key=156)...
# [train] Procesando 742R (key=742)...
# [train] Procesando 1024R (key=1024)...
# [train] Procesando 1676R (key=1676)...
# [train] Procesando 1042R (key=1042)...
# [train] Procesando 1163R (key=1163)...
# [train] Procesando 31R (key=31)...
# [train] Procesando 144R (key=144)...
# [train] Procesando 712R (key=712)...
# [train] Procesando 1748R (key=1748)...
# [train] Procesando 375R (key=375)...
# [train] Procesando 1323R (key=1323)...
# [train] Procesando 364R (key=364)...
# [train] Procesando 583R (key=583)...
# [train] Procesando 1584R (key=1584)...
# [train] Procesando 562R (key=562)...
# [train] Procesando 556R (key=556)...
# [train] Procesando 1505R (key=1505)...
# [train] Procesando 139R (key=139)...
# [train] Procesando 1348R (key=1348)...
# [train] Procesando 1421R (key=1421)...
# [train] Procesando 1162R (key=1162)...
# [train] Procesando 977R (key=977)...
# [train] Procesando 1071R (key=1071)...
# [train] Procesando 51R (key=51)...
# [train] Procesando 1509R (key=1509)...
# [train] Procesando 378R (key=378)...
# [train] Procesando 1781R (key=1781)...
# [train] Procesando 250R (key=250)...
# [train] Procesando 993R (key=993)...
# [train] Procesando 915R (key=915)...
# [train] Procesando 1621R (key=1621)...
# [train] Procesando 350R (key=350)...
# [train] Procesando 442R (key=442)...
# [train] Procesando 261R (key=261)...
# [train] Procesando 245R (key=245)...
# [train] Procesando 381R (key=381)...
# [train] Procesando 1079R (key=1079)...
# [train] Procesando 254R (key=254)...
# [train] Procesando 1464R (key=1464)...
# [train] Procesando 697R (key=697)...
# [train] Procesando 1073R (key=1073)...
# [train] Procesando 1788R (key=1788)...
# [train] Procesando 1510R (key=1510)...
# [train] Procesando 27R (key=27)...
# [train] Procesando 103R (key=103)...
# [train] Procesando 1175R (key=1175)...
# [train] Procesando 952R (key=952)...
# [train] Procesando 1538R (key=1538)...
# [train] Procesando 1493R (key=1493)...
# [train] Procesando 34R (key=34)...
# [train] Procesando 519R (key=519)...
# [train] Procesando 1083R (key=1083)...
# [train] Procesando 1332R (key=1332)...
# [train] Procesando 542R (key=542)...
# [train] Procesando 23R (key=23)...
# [train] Procesando 1753R (key=1753)...
# [train] Procesando 74R (key=74)...
# [train] Procesando 1412R (key=1412)...
# [train] Procesando 140R (key=140)...
# [train] Procesando 18R (key=18)...
# [train] Procesando 3R (key=3)...
# [train] Procesando 567R (key=567)...
# [train] Procesando 855R (key=855)...
# [train] Procesando 1337R (key=1337)...
# [train] Procesando 324R (key=324)...
# [train] Procesando 433R (key=433)...
# [train] Procesando 1237R (key=1237)...
# [train] Procesando 1643R (key=1643)...
# [train] Procesando 530R (key=530)...
# [train] Procesando 671R (key=671)...
# [train] Procesando 536R (key=536)...
# [train] Procesando 970R (key=970)...
# [train] Procesando 672R (key=672)...
# [train] Procesando 1319R (key=1319)...
# [train] Procesando 740R (key=740)...
# [train] Procesando 1396R (key=1396)...
# [train] Procesando 1326R (key=1326)...
# [train] Procesando 188R (key=188)...
# [train] Procesando 990R (key=990)...
# [train] Procesando 290R (key=290)...
# [train] Procesando 1232R (key=1232)...
# [train] Procesando 1197R (key=1197)...
# [train] Procesando 213R (key=213)...
# [train] Procesando 1712R (key=1712)...
# [train] Procesando 158R (key=158)...
# [train] Procesando 553R (key=553)...
# [train] Procesando 982R (key=982)...
# [train] Procesando 410R (key=410)...
# [train] Procesando 189R (key=189)...
# [train] Procesando 1613R (key=1613)...
# [train] Procesando 153R (key=153)...
# [train] Procesando 1693R (key=1693)...
# [train] Procesando 1734R (key=1734)...
# [train] Procesando 1200R (key=1200)...
# [train] Procesando 918R (key=918)...
# [train] Procesando 193R (key=193)...
# [train] Procesando 493R (key=493)...
# [train] Procesando 333R (key=333)...
# [train] Procesando 443R (key=443)...
# [train] Procesando 1253R (key=1253)...
# [train] Procesando 1592R (key=1592)...
# [train] Procesando 1746R (key=1746)...
# [train] Procesando 821R (key=821)...
# [train] Procesando 552R (key=552)...
# [train] Procesando 365R (key=365)...
# [train] Procesando 1413R (key=1413)...
# [train] Procesando 522R (key=522)...
# [train] Procesando 504R (key=504)...
# [train] Procesando 1649R (key=1649)...
# [train] Procesando 731R (key=731)...
# [train] Procesando 469R (key=469)...
# [train] Procesando 1185R (key=1185)...
# [train] Procesando 224R (key=224)...
# [train] Procesando 1311R (key=1311)...
# [train] Procesando 448R (key=448)...
# [train] Procesando 1300R (key=1300)...
# [train] Procesando 944R (key=944)...
# [train] Procesando 54R (key=54)...
# [train] Procesando 1485R (key=1485)...
# [train] Procesando 1296R (key=1296)...
# [train] Procesando 1266R (key=1266)...
# [train] Procesando 1587R (key=1587)...
# [train] Procesando 463R (key=463)...
# [train] Procesando 1067R (key=1067)...
# [train] Procesando 1744R (key=1744)...
# [train] Procesando 340R (key=340)...
# [train] Procesando 521R (key=521)...
# [train] Procesando 1733R (key=1733)...
# [train] Procesando 291R (key=291)...
# [train] Procesando 169R (key=169)...
# [train] Procesando 842R (key=842)...
# [train] Procesando 673R (key=673)...
# [train] Procesando 1121R (key=1121)...
# [train] Procesando 1303R (key=1303)...
# [train] Procesando 1389R (key=1389)...
# [train] Procesando 1061R (key=1061)...
# [train] Procesando 665R (key=665)...
# [train] Procesando 780R (key=780)...
# [train] Procesando 29R (key=29)...
# [train] Procesando 979R (key=979)...
# [train] Procesando 916R (key=916)...
# [train] Procesando 635R (key=635)...
# [train] Procesando 1664R (key=1664)...
# [train] Procesando 727R (key=727)...
# [train] Procesando 401R (key=401)...
# [train] Procesando 260R (key=260)...
# [train] Procesando 844R (key=844)...
# [train] Procesando 1241R (key=1241)...
# [train] Procesando 667R (key=667)...
# [train] Procesando 267R (key=267)...
# [train] Procesando 1346R (key=1346)...
# [train] Procesando 211R (key=211)...
# [train] Procesando 384R (key=384)...
# [train] Procesando 335R (key=335)...
# [train] Procesando 394R (key=394)...
# [train] Procesando 1376R (key=1376)...
# [train] Procesando 526R (key=526)...
# [train] Procesando 1790R (key=1790)...
# ...
# [test] Procesando 603R (key=603)...
# [test] Procesando 604R (key=604)...
# [test] Procesando 605R (key=605)...
# [test] Procesando 606R (key=606)...
# [test] Procesando 607R (key=607)...
# [test] Procesando 608R (key=608)...
# [test] Procesando 609R (key=609)...
# [test] Procesando 60R (key=60)...
# [test] Procesando 610R (key=610)...
# [test] Procesando 611R (key=611)...
# [test] Procesando 612R (key=612)...
# [test] Procesando 613R (key=613)...
# [test] Procesando 614R (key=614)...
# [test] Procesando 615R (key=615)...
# [test] Procesando 616R (key=616)...
# [test] Procesando 617R (key=617)...
# [test] Procesando 618R (key=618)...
# [test] Procesando 619R (key=619)...
# [test] Procesando 61R (key=61)...
# [test] Procesando 620R (key=620)...
# [test] Procesando 621R (key=621)...
# [test] Procesando 622R (key=622)...
# [test] Procesando 623R (key=623)...
# [test] Procesando 624R (key=624)...
# [test] Procesando 625R (key=625)...
# [test] Procesando 626R (key=626)...
# [test] Procesando 627R (key=627)...
# [test] Procesando 628R (key=628)...
# [test] Procesando 629R (key=629)...
# [test] Procesando 62R (key=62)...
# [test] Procesando 630R (key=630)...
# [test] Procesando 631R (key=631)...
# [test] Procesando 632R (key=632)...
# [test] Procesando 633R (key=633)...
# [test] Procesando 634R (key=634)...
# [test] Procesando 635R (key=635)...
# [test] Procesando 636R (key=636)...
# [test] Procesando 637R (key=637)...
# [test] Procesando 638R (key=638)...
# [test] Procesando 639R (key=639)...
# [test] Procesando 63R (key=63)...
# [test] Procesando 640R (key=640)...
# [test] Procesando 641R (key=641)...
# [test] Procesando 642R (key=642)...
# [test] Procesando 643R (key=643)...
# [test] Procesando 644R (key=644)...
# [test] Procesando 645R (key=645)...
# [test] Procesando 646R (key=646)...
# [test] Procesando 647R (key=647)...
# [test] Procesando 648R (key=648)...
# [test] Procesando 649R (key=649)...
# [test] Procesando 64R (key=64)...
# [test] Procesando 650R (key=650)...
# [test] Procesando 651R (key=651)...
# [test] Procesando 652R (key=652)...
# [test] Procesando 653R (key=653)...
# [test] Procesando 654R (key=654)...
# [test] Procesando 655R (key=655)...
# [test] Procesando 656R (key=656)...
# [test] Procesando 657R (key=657)...
# [test] Procesando 658R (key=658)...
# [test] Procesando 659R (key=659)...
# [test] Procesando 65R (key=65)...
# [test] Procesando 660R (key=660)...
# [test] Procesando 661R (key=661)...
# [test] Procesando 662R (key=662)...
# [test] Procesando 663R (key=663)...
# [test] Procesando 664R (key=664)...
# [test] Procesando 665R (key=665)...
# [test] Procesando 666R (key=666)...
# [test] Procesando 667R (key=667)...
# [test] Procesando 668R (key=668)...
# [test] Procesando 669R (key=669)...
# [test] Procesando 66R (key=66)...
# [test] Procesando 670R (key=670)...
# [test] Procesando 671R (key=671)...
# [test] Procesando 672R (key=672)...
# [test] Procesando 673R (key=673)...
# [test] Procesando 674R (key=674)...
# [test] Procesando 675R (key=675)...
# [test] Procesando 676R (key=676)...
# [test] Procesando 677R (key=677)...
# [test] Procesando 678R (key=678)...
# [test] Procesando 679R (key=679)...
# [test] Procesando 67R (key=67)...
# [test] Procesando 680R (key=680)...
# [test] Procesando 681R (key=681)...
# [test] Procesando 682R (key=682)...
# [test] Procesando 683R (key=683)...
# [test] Procesando 684R (key=684)...
# [test] Procesando 685R (key=685)...
# [test] Procesando 686R (key=686)...
# [test] Procesando 687R (key=687)...
# [test] Procesando 688R (key=688)...
# [test] Procesando 689R (key=689)...
# [test] Procesando 68R (key=68)...
# [test] Procesando 690R (key=690)...
# [test] Procesando 691R (key=691)...
# [test] Procesando 692R (key=692)...
# [test] Procesando 693R (key=693)...
# [test] Procesando 694R (key=694)...
# [test] Procesando 695R (key=695)...
# [test] Procesando 696R (key=696)...
# [test] Procesando 697R (key=697)...
# [test] Procesando 698R (key=698)...
# [test] Procesando 699R (key=699)...
# [test] Procesando 69R (key=69)...
# [test] Procesando 6R (key=6)...
# [test] Procesando 700R (key=700)...
# [test] Procesando 701R (key=701)...
# [test] Procesando 702R (key=702)...
# [test] Procesando 703R (key=703)...
# [test] Procesando 704R (key=704)...
# [test] Procesando 705R (key=705)...
# [test] Procesando 706R (key=706)...
# [test] Procesando 707R (key=707)...
# [test] Procesando 708R (key=708)...
# [test] Procesando 709R (key=709)...
# [test] Procesando 70R (key=70)...
# [test] Procesando 710R (key=710)...
# [test] Procesando 711R (key=711)...
# [test] Procesando 712R (key=712)...
# [test] Procesando 713R (key=713)...
# [test] Procesando 714R (key=714)...
# [test] Procesando 715R (key=715)...
# [test] Procesando 716R (key=716)...
# [test] Procesando 717R (key=717)...
# [test] Procesando 718R (key=718)...
# [test] Procesando 719R (key=719)...
# [test] Procesando 71R (key=71)...
# [test] Procesando 720R (key=720)...
# [test] Procesando 721R (key=721)...
# [test] Procesando 722R (key=722)...
# [test] Procesando 723R (key=723)...
# [test] Procesando 724R (key=724)...
# [test] Procesando 725R (key=725)...
# [test] Procesando 726R (key=726)...
# [test] Procesando 727R (key=727)...
# [test] Procesando 728R (key=728)...
# [test] Procesando 729R (key=729)...
# [test] Procesando 72R (key=72)...
# [test] Procesando 730R (key=730)...
# [test] Procesando 731R (key=731)...
# [test] Procesando 732R (key=732)...
# [test] Procesando 733R (key=733)...
# [test] Procesando 734R (key=734)...
# [test] Procesando 735R (key=735)...
# [test] Procesando 736R (key=736)...
# [test] Procesando 737R (key=737)...
# [test] Procesando 738R (key=738)...
# [test] Procesando 739R (key=739)...
# [test] Procesando 73R (key=73)...
# [test] Procesando 740R (key=740)...
# [test] Procesando 741R (key=741)...
# [test] Procesando 742R (key=742)...
# [test] Procesando 743R (key=743)...
# [test] Procesando 744R (key=744)...
# [test] Procesando 745R (key=745)...
# [test] Procesando 746R (key=746)...
# [test] Procesando 747R (key=747)...
# [test] Procesando 748R (key=748)...
# [test] Procesando 749R (key=749)...
# [test] Procesando 74R (key=74)...
# [test] Procesando 750R (key=750)...
# [test] Procesando 751R (key=751)...
# [test] Procesando 752R (key=752)...
# [test] Procesando 753R (key=753)...
# [test] Procesando 754R (key=754)...
# [test] Procesando 755R (key=755)...
# [test] Procesando 756R (key=756)...
# [test] Procesando 757R (key=757)...
# [test] Procesando 758R (key=758)...
# [test] Procesando 759R (key=759)...
# [test] Procesando 75R (key=75)...
# [test] Procesando 760R (key=760)...
# [test] Procesando 761R (key=761)...
# [test] Procesando 762R (key=762)...
# [test] Procesando 763R (key=763)...
# [test] Procesando 764R (key=764)...
# [test] Procesando 765R (key=765)...
# [test] Procesando 766R (key=766)...
# [test] Procesando 767R (key=767)...
# [test] Procesando 768R (key=768)...
# [test] Procesando 769R (key=769)...
# [test] Procesando 76R (key=76)...
# [test] Procesando 770R (key=770)...
# [test] Procesando 771R (key=771)...
# [test] Procesando 772R (key=772)...
# [test] Procesando 773R (key=773)...
# [test] Procesando 774R (key=774)...
# [test] Procesando 775R (key=775)...
# [test] Procesando 776R (key=776)...
# [test] Procesando 777R (key=777)...
# [test] Procesando 778R (key=778)...
# [test] Procesando 779R (key=779)...
# [test] Procesando 77R (key=77)...
# [test] Procesando 780R (key=780)...
# [test] Procesando 781R (key=781)...
# [test] Procesando 782R (key=782)...
# [test] Procesando 783R (key=783)...
# [test] Procesando 784R (key=784)...
# [test] Procesando 785R (key=785)...
# [test] Procesando 786R (key=786)...
# [test] Procesando 787R (key=787)...
# [test] Procesando 788R (key=788)...
# [test] Procesando 789R (key=789)...
# [test] Procesando 78R (key=78)...
# [test] Procesando 790R (key=790)...
# [test] Procesando 791R (key=791)...
# [test] Procesando 792R (key=792)...
# [test] Procesando 793R (key=793)...
# [test] Procesando 794R (key=794)...
# [test] Procesando 795R (key=795)...
# [test] Procesando 796R (key=796)...
# [test] Procesando 797R (key=797)...
# [test] Procesando 798R (key=798)...
# [test] Procesando 799R (key=799)...
# [test] Procesando 79R (key=79)...
# [test] Procesando 7R (key=7)...
# [test] Procesando 800R (key=800)...
# [test] Procesando 801R (key=801)...
# [test] Procesando 802R (key=802)...
# [test] Procesando 803R (key=803)...
# [test] Procesando 804R (key=804)...
# [test] Procesando 805R (key=805)...
# [test] Procesando 806R (key=806)...
# [test] Procesando 807R (key=807)...
# [test] Procesando 808R (key=808)...
# [test] Procesando 809R (key=809)...
# [test] Procesando 80R (key=80)...
# [test] Procesando 810R (key=810)...
# [test] Procesando 811R (key=811)...
# [test] Procesando 812R (key=812)...
# [test] Procesando 813R (key=813)...
# [test] Procesando 814R (key=814)...
# [test] Procesando 815R (key=815)...
# [test] Procesando 816R (key=816)...
# [test] Procesando 817R (key=817)...
# [test] Procesando 818R (key=818)...
# [test] Procesando 819R (key=819)...
# [test] Procesando 81R (key=81)...
# [test] Procesando 820R (key=820)...
# [test] Procesando 821R (key=821)...
# [test] Procesando 822R (key=822)...
# [test] Procesando 823R (key=823)...
# [test] Procesando 824R (key=824)...
# [test] Procesando 825R (key=825)...
# [test] Procesando 826R (key=826)...
# [test] Procesando 827R (key=827)...
# [test] Procesando 828R (key=828)...
# [test] Procesando 829R (key=829)...
# [test] Procesando 82R (key=82)...
# [test] Procesando 830R (key=830)...
# [test] Procesando 831R (key=831)...
# [test] Procesando 832R (key=832)...
# [test] Procesando 833R (key=833)...
# [test] Procesando 834R (key=834)...
# [test] Procesando 835R (key=835)...
# [test] Procesando 836R (key=836)...
# [test] Procesando 837R (key=837)...
# [test] Procesando 838R (key=838)...
# [test] Procesando 839R (key=839)...
# [test] Procesando 83R (key=83)...
# [test] Procesando 840R (key=840)...
# [test] Procesando 841R (key=841)...
# [test] Procesando 842R (key=842)...
# [test] Procesando 843R (key=843)...
# [test] Procesando 844R (key=844)...
# [test] Procesando 845R (key=845)...
# [test] Procesando 846R (key=846)...
# [test] Procesando 847R (key=847)...
# [test] Procesando 848R (key=848)...
# [test] Procesando 849R (key=849)...
# [test] Procesando 84R (key=84)...
# [test] Procesando 850R (key=850)...
# [test] Procesando 851R (key=851)...
# [test] Procesando 852R (key=852)...
# [test] Procesando 853R (key=853)...
# [test] Procesando 854R (key=854)...
# [test] Procesando 855R (key=855)...
# [test] Procesando 856R (key=856)...
# [test] Procesando 857R (key=857)...
# [test] Procesando 858R (key=858)...
# [test] Procesando 859R (key=859)...
# [test] Procesando 85R (key=85)...
# [test] Procesando 860R (key=860)...
# [test] Procesando 861R (key=861)...
# [test] Procesando 862R (key=862)...
# [test] Procesando 863R (key=863)...
# [test] Procesando 864R (key=864)...
# [test] Procesando 865R (key=865)...
# [test] Procesando 866R (key=866)...
# [test] Procesando 867R (key=867)...
# [test] Procesando 868R (key=868)...
# [test] Procesando 869R (key=869)...
# [test] Procesando 86R (key=86)...
# [test] Procesando 870R (key=870)...
# [test] Procesando 871R (key=871)...
# [test] Procesando 872R (key=872)...
# [test] Procesando 873R (key=873)...
# [test] Procesando 874R (key=874)...
# [test] Procesando 875R (key=875)...
# [test] Procesando 876R (key=876)...
# [test] Procesando 877R (key=877)...
# [test] Procesando 878R (key=878)...
# [test] Procesando 879R (key=879)...
# [test] Procesando 87R (key=87)...
# [test] Procesando 880R (key=880)...
# [test] Procesando 881R (key=881)...
# [test] Procesando 882R (key=882)...
# [test] Procesando 883R (key=883)...
# [test] Procesando 884R (key=884)...
# [test] Procesando 885R (key=885)...
# [test] Procesando 886R (key=886)...
# [test] Procesando 887R (key=887)...
# [test] Procesando 888R (key=888)...
# [test] Procesando 889R (key=889)...
# [test] Procesando 88R (key=88)...
# [test] Procesando 890R (key=890)...
# [test] Procesando 891R (key=891)...
# [test] Procesando 892R (key=892)...
# [test] Procesando 893R (key=893)...
# [test] Procesando 894R (key=894)...
# [test] Procesando 895R (key=895)...
# [test] Procesando 896R (key=896)...
# [test] Procesando 897R (key=897)...
# [test] Procesando 898R (key=898)...
# [test] Procesando 899R (key=899)...
# [test] Procesando 89R (key=89)...
# [test] Procesando 8R (key=8)...
# [test] Procesando 900R (key=900)...
# [test] Procesando 901R (key=901)...
# [test] Procesando 902R (key=902)...
# [test] Procesando 903R (key=903)...
# [test] Procesando 904R (key=904)...
# [test] Procesando 905R (key=905)...
# [test] Procesando 906R (key=906)...
# [test] Procesando 907R (key=907)...
# [test] Procesando 908R (key=908)...
# [test] Procesando 909R (key=909)...
# [test] Procesando 90R (key=90)...
# [test] Procesando 910R (key=910)...
# [test] Procesando 911R (key=911)...
# [test] Procesando 912R (key=912)...
# [test] Procesando 913R (key=913)...
# [test] Procesando 914R (key=914)...
# [test] Procesando 915R (key=915)...
# [test] Procesando 916R (key=916)...
# [test] Procesando 917R (key=917)...
# [test] Procesando 918R (key=918)...
# [test] Procesando 919R (key=919)...
# [test] Procesando 91R (key=91)...
# [test] Procesando 920R (key=920)...
# [test] Procesando 921R (key=921)...
# [test] Procesando 922R (key=922)...
# [test] Procesando 923R (key=923)...
# [test] Procesando 924R (key=924)...
# [test] Procesando 925R (key=925)...
# [test] Procesando 926R (key=926)...
# [test] Procesando 927R (key=927)...
# [test] Procesando 928R (key=928)...
# [test] Procesando 929R (key=929)...
# [test] Procesando 92R (key=92)...
# [test] Procesando 930R (key=930)...
# [test] Procesando 931R (key=931)...
# [test] Procesando 932R (key=932)...
# [test] Procesando 933R (key=933)...
# [test] Procesando 934R (key=934)...
# [test] Procesando 935R (key=935)...
# [test] Procesando 936R (key=936)...
# [test] Procesando 937R (key=937)...
# [test] Procesando 938R (key=938)...
# [test] Procesando 939R (key=939)...
# [test] Procesando 93R (key=93)...
# [test] Procesando 940R (key=940)...
# [test] Procesando 941R (key=941)...
# [test] Procesando 942R (key=942)...
# [test] Procesando 943R (key=943)...
# [test] Procesando 944R (key=944)...
# [test] Procesando 945R (key=945)...
# [test] Procesando 946R (key=946)...
# [test] Procesando 947R (key=947)...
# [test] Procesando 948R (key=948)...
# [test] Procesando 949R (key=949)...
# [test] Procesando 94R (key=94)...
# [test] Procesando 950R (key=950)...
# [test] Procesando 951R (key=951)...
# [test] Procesando 952R (key=952)...
# [test] Procesando 953R (key=953)...
# [test] Procesando 954R (key=954)...
# [test] Procesando 955R (key=955)...
# [test] Procesando 956R (key=956)...
# [test] Procesando 957R (key=957)...
# [test] Procesando 958R (key=958)...
# [test] Procesando 959R (key=959)...
# [test] Procesando 95R (key=95)...
# [test] Procesando 960R (key=960)...
# [test] Procesando 961R (key=961)...
# [test] Procesando 962R (key=962)...
# [test] Procesando 963R (key=963)...
# [test] Procesando 964R (key=964)...
# [test] Procesando 965R (key=965)...
# [test] Procesando 966R (key=966)...
# [test] Procesando 967R (key=967)...
# [test] Procesando 968R (key=968)...
# [test] Procesando 969R (key=969)...
# [test] Procesando 96R (key=96)...
# [test] Procesando 970R (key=970)...
# [test] Procesando 971R (key=971)...
# [test] Procesando 972R (key=972)...
# [test] Procesando 973R (key=973)...
# [test] Procesando 974R (key=974)...
# [test] Procesando 975R (key=975)...
# [test] Procesando 976R (key=976)...
# [test] Procesando 977R (key=977)...
# [test] Procesando 978R (key=978)...
# [test] Procesando 979R (key=979)...
# [test] Procesando 97R (key=97)...
# [test] Procesando 980R (key=980)...
# [test] Procesando 981R (key=981)...
# [test] Procesando 982R (key=982)...
# [test] Procesando 983R (key=983)...
# [test] Procesando 984R (key=984)...
# [test] Procesando 985R (key=985)...
# [test] Procesando 986R (key=986)...
# [test] Procesando 987R (key=987)...
# [test] Procesando 988R (key=988)...
# [test] Procesando 989R (key=989)...
# [test] Procesando 98R (key=98)...
# [test] Procesando 990R (key=990)...
# [test] Procesando 991R (key=991)...
# [test] Procesando 992R (key=992)...
# [test] Procesando 993R (key=993)...
# [test] Procesando 994R (key=994)...
# [test] Procesando 995R (key=995)...
# [test] Procesando 996R (key=996)...
# [test] Procesando 997R (key=997)...
# [test] Procesando 998R (key=998)...
# [test] Procesando 999R (key=999)...
# [test] Procesando 99R (key=99)...
# [test] Procesando 9R (key=9)...
# [test] XML totales: 1800
# [test] Pares OK (img+T+label): 1799
# [test] Sin imágenes emparejadas: 0
# [test] Sin labels (0 personas): 1
# ✔ Dataset DroneRGBT convertido a formato YOLO rgb+t en: data\DroneRGBT\format_rgbt

# %%
from pathlib import Path
from ultralytics import YOLO

# Tus utilidades existentes (NO se tocan)
from src.utils_MF import run_middle_fusion_split, print_metrics
from src.utils_LF import evaluate_yolo_predictions

# %%
ROOT = Path().resolve()

DATA_ROOT = ROOT / "data" / "DroneRGBT" / "format_rgbt"

# Rutas RGB y T
VAL_RGB_DIR  = DATA_ROOT / "images" / "val" / "rgb"
VAL_T_DIR    = DATA_ROOT / "images" / "val" / "t"

TEST_RGB_DIR = DATA_ROOT / "images" / "test" / "rgb"
TEST_T_DIR   = DATA_ROOT / "images" / "test" / "t"

GT_VAL_DIR   = DATA_ROOT / "labels" / "val"
GT_TEST_DIR  = DATA_ROOT / "labels" / "test"

# %%
model_rgb = YOLO("runs/detect/dronergbt_rgb/weights/best.pt")
model_t   = YOLO("runs/detect/dronergbt_t/weights/best.pt")

print("Modelos cargados para DroneRGBT:")
print("  RGB -> runs/detect/dronergbt_rgb/weights/best.pt")
print("  T   -> runs/detect/dronergbt_t/weights/best.pt")

# %%
OUT_IMG_MF_VAL_DIR  = ROOT / "runs" / "middle_fusion_dronergbt" / "val"
OUT_PRED_MF_VAL_DIR = ROOT / "runs" / "middle_fusion_dronergbt" / "preds_val"

OUT_IMG_MF_TEST_DIR  = ROOT / "runs" / "middle_fusion_dronergbt" / "test"
OUT_PRED_MF_TEST_DIR = ROOT / "runs" / "middle_fusion_dronergbt" / "preds_test"

for d in [
    OUT_IMG_MF_VAL_DIR, OUT_PRED_MF_VAL_DIR,
    OUT_IMG_MF_TEST_DIR, OUT_PRED_MF_TEST_DIR
]:
    d.mkdir(parents=True, exist_ok=True)

# %%
NUM_CLASSES = 1
CLASS_LABELS = ["Person"]

# %%
print("\n=== Middle Fusion (VAL) ===")

run_middle_fusion_split(
    model_rgb=model_rgb,
    model_t=model_t,
    class_names={0: "Person"},
    rgb_dir=VAL_RGB_DIR,
    t_dir=VAL_T_DIR,
    out_img_dir=OUT_IMG_MF_VAL_DIR,
    out_pred_dir=OUT_PRED_MF_VAL_DIR,
    img_size=640,
)

metrics_mf_val = evaluate_yolo_predictions(
    pred_dir=OUT_PRED_MF_VAL_DIR,
    gt_dir=GT_VAL_DIR,
    num_classes=NUM_CLASSES,
    iou_threshold=0.5,
)

print_metrics("Middle Fusion (VAL)", metrics_mf_val)

# %%
print("\n=== Middle Fusion (TEST) ===")

run_middle_fusion_split(
    model_rgb=model_rgb,
    model_t=model_t,
    class_names={0: "Person"},
    rgb_dir=TEST_RGB_DIR,
    t_dir=TEST_T_DIR,
    out_img_dir=OUT_IMG_MF_TEST_DIR,
    out_pred_dir=OUT_PRED_MF_TEST_DIR,
    img_size=640,
)

metrics_mf_test = evaluate_yolo_predictions(
    pred_dir=OUT_PRED_MF_TEST_DIR,
    gt_dir=GT_TEST_DIR,
    num_classes=NUM_CLASSES,
    iou_threshold=0.5,
)

print_metrics("Middle Fusion (TEST)", metrics_mf_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 5
#       2 from ultralytics import YOLO
#       4 # Tus utilidades existentes (NO se tocan)
# ----> 5 from utils_MF import run_middle_fusion_split, print_metrics
#       6 from utils_LF import evaluate_yolo_predictions
#       8 # ============================================================
#       9 #     CONFIGURACIÓN DE RUTAS PARA DRONERGBT (NUEVO DATASET)
#      10 # ============================================================
#
# ModuleNotFoundError: No module named 'utils_MF'
